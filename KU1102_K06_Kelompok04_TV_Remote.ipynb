# %% [markdown]
# <a href="https://colab.research.google.com/github/keishapq31/keishapq31/blob/main/KU1102_K06_Kelompok04_TV_Remote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TV Remote Controller Program Model
# Program TV Remote sederhana yang dapat dilakukan 8 fungsi
# KU1102_Pengenalan Komputasi K06 FITB
# Kelompok 4
# 1. Azkiya T (16321013)
# 2. Syifa Kamiliya (16321017)
# 3. Keisha Prillia Q (16321021)
# 4. Bunga Azzahra (16321245)

# KAMUS
# Stat      : str
# V, C      : int
# CList     : array str

# ALGORITMA

print("TV Remote Controller Program")
print("""

1. Turn On TV
2. Turn Off TV
3. Volume Adjustmment
4. Channel List and Amount
5. Add Channel
6. Move Channel
7. Move to a Certain Channel
8. TV Info

To Exit, press 'Q' or 'q'

""")

# Keterangan TV yang pre-defined, yaitu Status TV, Volume, Channel dan List Channel
Stat = "OFF"
V = int(25)
C = int(7)
CList = ["KompasTV", "GlobalTV", "TransTV", "Trans7", "RCTI", "TvOne", "HBO", "FOX", "BBC", "Nickelodeon"]

while True:
    Op = input("Choose Operation: ")
    print("")
    if (Op == "Q") or (Op == "q"):                      # Command untuk menutup program TV Remote/tidak jadi mengatur TV
        print("Closing Program...")
        break
    elif (Op == "1"):                                   # Command untuk menyalakan TV
        if (Stat == "ON"):
            print("_TV is On.")                         # Output text jika TV sudah menyala
            print("")
        else:
            print("_Turning TV On...")                  # Output text jika TV belum menyala
            print("")
            Stat = "ON"
    elif (Op == "2"):                                   # Command untuk mematikan TV
        if (Stat == "OFF"):
            print("_TV is Off.")                        # Output text jika TV sudah mati
            print("")
        else:
            print("_Turning TV Off...")                 # Output text jika TV belum mati
            print("")
            Stat = "OFF"
    elif (Stat == "ON") and (Op == "3"):                # Command untuk mengatur volume suara TV
        while True:                                     # Looping pengaturan volume suara TV
            print("Volume Down: '-' \nVolume Up: '+' \nMute: 'M' \nExit: 'Q' or 'q'")
            A = input("__Input Operation: ")
            if (A == "-"):                              # Command untuk mengurangi volume suara TV
                if (0 < V <= 100):                      # Ketentuan volume awal yang bisa diturunkan volumenya
                    V -= 1
                    print("___Volume: ", V)             # Output text volume suara yang telah diatur
                    print("")
                elif (V == 0):
                    print("You are currently at the Minimum Volume!")
            elif (A == "+"):                            # Command untuk menambah volume
                if (0 <= V < 100):                      # Ketentuan volume awal yang bisa ditambah volumenya
                    V += 1
                    print("___Volume: ", V)             # Output text volume suara yang telah diatur
                    print("")
                elif (V == 100):
                    print("You are currently at the Maximum Volume!")
            elif (A == "M"):                            # Command untuk membisukan suara TV
                if (0 <= V <= 100):                      # Ketentuan volume awal yang bisa dibisukan
                    V = 0
                    print("___TV has been Muted.")      # Output text volume suara yang telah diatur
                    print("")
            elif (A == "q") or (A == "Q"):              # Command untuk keluar dari program pengaturan volume suara TV
                print("___Volume has been Updated! Volume:", V) # Output text pasca exit program pengaturan volume
                print("")
                break
            else:                                       # Bila command yang dimasukkan tidak terdefinisi
                print("___Invalid Operation! Please Try Again.") # Output text jika command tidak terdefinisi
                print("")
    elif (Stat == "ON") and (Op == "4"):                # Command untuk melihat jumlah channel yang terdapat di TV
        for x in CList:
            print(x)
        print("_Channel Amount: ", len(CList))          # Output jumlah channel yang ada
        print("")
    elif (Stat == "ON") and (Op == "5"):                # Command untuk menambahkan channel baru
        CName = str(input("_Add New Channel: "))        # Input dari user, nama channel (string)
        CList.append(CName)
        print("__Channel", CName, "has been added.")    # Output text channel yang sudah ditambahkan dalam list
        print("")
    elif (Stat == "ON") and (Op == "6"):                # Command untuk memindahkan channel
        while True:                                     # Looping pengaturan channel TV
            print("Previous Channel: '-' \nNext Channel: '+' \nExit: 'Q' or 'q'")
            a = input("___Input Operation: ")
            print("")
            if (a == "-"):                              # Command untuk pindah satu channel ke bawah
                if (0 < C <= (len(CList)-1)):               # Ketentuan nomor channel yang bisa dipindah ke bawah
                    C -= 1
                    print("___Moved to the Previous Channel")   # Output text operasi pemindahan channel
                    print("___Now Watching Channel", C) # Output text channel yang telah dipindahkan
                    print("")
                elif (C == 0):                          # Ketentuan channel paling awal dan tidak bisa dipindah ke bawah
                    print("___There are no more Channels before this!") # Output text channel tidak bisa dipindah ke bawah
                    print("")
            elif (a == "+"):                            # Command untuk pindah satu channel ke atas
                if (0 <= C < (len(CList)-1)):               # Ketentuan nomor channel yang bisa dipindah ke atas
                    C += 1
                    print("___Moved to the Next Channel")   # Output text operasi pemindahan channel
                    print("___Now Watching Channel", C) # Output text channel yang telah dipindahkan
                    print("")
                elif (C == (len(CList)-1)):                 # Ketentuan channel paling akhir dan tidak bisa dipindah ke atas
                    print("___There are no more Channels after this!")  # Output text channel tidak bisa dipindah ke atas
                    print("")
            elif (a == "q") or (a == "Q"):              # Command untuk keluar dari program pengaturan channel
                print("___Channel has been moved!")     # Output text pasca exit program pengaturan channel
                print("___Now Watching Channel", C)
                print("")
                break
            else:
                print("___Invalid Operation! Please Try Again") # Output text jika command tidak terdefinisi
                print("")
    elif (Stat == "ON") and (Op == "7"):                # Command untuk mengubah ke channel tertentu
        while True:
            C = int(input("__Designated Channel Number: "))
            if C in range (len(CList)):
                Ch = CList[C]
                print("___Moved to Channel", C, Ch)
                print("")
                break
            else:
                print("Channel is not in Range!")
                print("")
    elif (Stat == "ON") and (Op == "8"):                # Command untuk melihat status TV
        print("_TV Status: ", Stat)
        print("_TV Volume: ", V)
        print("_Channel Amount: ", len(CList))
        print("_Watching Channel:", C, CList[C])
        print("")
    else:
        print("Invalid Operation!")
# Out:
# TV Remote Controller Program
#
#
# 1. Turn On TV
# 2. Turn Off TV
# 3. Volume Adjustmment
# 4. Channel List and Amount
# 5. Add Channel
# 6. Move Channel
# 7. Move to a Certain Channel
# 8. TV Info
#
# To Exit, press 'Q' or 'q'
#
#
# Choose Operation: 1
#
# _Turning TV On...
#
# Choose Operation: 3
#
# Volume Down: '-'
# Volume Up: '+'
# Mute: 'M'
# Exit: 'Q' or 'q'
# __Input Operation: +
# ___Volume:  26
#
# Volume Down: '-'
# Volume Up: '+'
# Mute: 'M'
# Exit: 'Q' or 'q'
# __Input Operation: +
# ___Volume:  27
#
# Volume Down: '-'
# Volume Up: '+'
# Mute: 'M'
# Exit: 'Q' or 'q'
# __Input Operation: M
# ___TV has been Muted.
#
# Volume Down: '-'
# Volume Up: '+'
# Mute: 'M'
# Exit: 'Q' or 'q'
# __Input Operation: q
# ___Volume has been Updated! Volume: 0
#
# Choose Operation: 4
#
# KompasTV
# GlobalTV
# TransTV
# Trans7
# RCTI
# TvOne
# HBO
# FOX
# BBC
# Nickelodeon
# _Channel Amount:  10
#
# Choose Operation: 5
#
# _Add New Channel: CNN
# __Channel CNN has been added.
#
# Choose Operation: 4
#
# KompasTV
# GlobalTV
# TransTV
# Trans7
# RCTI
# TvOne
# HBO
# FOX
# BBC
# Nickelodeon
# CNN
# _Channel Amount:  11
#
# Choose Operation: 6
#
# Previous Channel: '-'
# Next Channel: '+'
# Exit: 'Q' or 'q'
# ___Input Operation: +
#
# ___Moved to the Next Channel
# ___Now Watching Channel 8
#
# Previous Channel: '-'
# Next Channel: '+'
# Exit: 'Q' or 'q'
# ___Input Operation: +
#
# ___Moved to the Next Channel
# ___Now Watching Channel 9
#
# Previous Channel: '-'
# Next Channel: '+'
# Exit: 'Q' or 'q'
# ___Input Operation: q
#
# ___Channel has been moved!
# ___Now Watching Channel 9
#
# Choose Operation: 7
#
# __Designated Channel Number: 23
# Channel is not in Range!
#
# __Designated Channel Number: 10
# ___Moved to Channel 10 CNN
#
# Choose Operation: 8
#
# _TV Status:  ON
# _TV Volume:  0
# _Channel Amount:  11
# _Watching Channel: 10 CNN
#
# Choose Operation: 2
#
# _Turning TV Off...
#
# Choose Operation: q
#
# Closing Program...
